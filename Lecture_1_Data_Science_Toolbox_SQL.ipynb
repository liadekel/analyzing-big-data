# %% [markdown]
# <a href="https://colab.research.google.com/github/liadekel/analyzing-big-data/blob/master/Lecture_1_Data_Science_Toolbox_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with Structured Data - SQL
# ### [The Art of Analyzing Big Data - The Data Scientist’s Toolbox - Lecture 1](https://www.ise.bgu.ac.il/labs/fire/lectures.html)
# #### By Dr. Michael Fire
#
# ----
#
# The following notebook has three parts. In the first part, we will setup the Kaggle package and use it to download a dataset. In the second part, we will present several examples of how to use Python & SQLite to analyze structure data. Lastly, we see some examples of how to work with Object-Relational Mapping (ORM) and the Pony ORM package.

# %% [markdown]
# ## 1. Setting Kaggle's Datasets API
#
# This is our first notebook. So first, let's get a Kaggle API key, and create  easy access to download Kaggle's datasets.
# More details on Kaggle's API can be found in the following [link](https://github.com/Kaggle/kaggle-api#api-credentials). Moreover, a quick explanation on how to get an API key and use it can be found in the following [link](https://gist.github.com/jayspeidell/d10b84b8d3da52df723beacc5b15cb27)

# %%
# !mkdir /root/.kaggle/

# %%
import json
import os

# Installing the Kaggle package
# !pip install kaggle 

#Important Note: complete this with your own key - after running this for the first time remmember to **remove** your API_KEY
#api_token = {"username":"<Insert Your Kaggle User Name>","key":"<Insert Your Kaggle API key>"}


# creating kaggle.json file with the personal API-Key details 
# You can also put this file on your Google Drive
with open('/root/.kaggle/kaggle.json', 'w') as file:
  json.dump(api_token, file)
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.6.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)

# %% [markdown]
# Let's check if we can use Kaggle API and download the [US Baby Names  dataset](https://www.kaggle.com/kaggle/us-baby-names)

# %%
# searching for the dataset
# !kaggle datasets list -s baby
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                      title                                         size  lastUpdated          downloadCount
# -------------------------------------------------------  -------------------------------------------  -----  -------------------  -------------
# kaggle/us-baby-names                                     US Baby Names                                173MB  2017-11-21 22:18:15          16945
# doyonghoon/baby-data                                     Baby data                                     40KB  2018-04-11 04:35:31            393
# new-york-city/nyc-baby-names                             NYC Baby Names                               136KB  2017-09-08 20:04:20            550
# roopalik/amazon-baby-dataset                             Amazon baby dataset                           18MB  2017-02-01 21:01:16            541
# samrat77/baby-names-dataset                              Baby Names DataSet                            85KB  2019-03-21 06:21:34            277
# ytmytm/babyfeeds                                         Baby girl breast feeds                        41KB  2019-07-14 18:31:46             90
# jpmiller/publicassistance                                US Public Assistance for Women and Children    3MB  2020-01-26 17:43:43           6259
# new-york-city/nyc-most-popular-baby-names                NYC Most Popular Baby Names                  150KB  2019-12-02 21:59:21            364
# xvivancos/barcelona-data-sets                            Barcelona data sets                            1MB  2020-02-15 23:29:29           9773
# netanel246/jewish-baby-names                             Jewish Baby Names                              4KB  2017-05-07 20:40:09             77
# hassenmorad/us-state-baby-names                          US State Baby Names                           41MB  2018-09-14 18:25:40             69
# hassenmorad/us-national-baby-names-18802017              US National Baby Names (1880-2017)             8MB  2018-09-14 17:35:52             65
# des137/us-births-2018                                    US births (2018)                             120MB  2019-11-28 09:26:32            163
# deepfriedtofu/baby-sloths                                Baby Sloths                                    2MB  2019-08-20 04:45:42              6
# sameersmahajan/reviews-of-amazon-baby-products           Reviews of Amazon Baby Products               29MB  2019-02-13 10:55:33            100
# cocowaffle/baby-photos                                   Baby Photos                                  115KB  2017-04-11 18:18:23            329
# fivethirtyeight/fivethirtyeight-drug-use-by-age-dataset  FiveThirtyEight Drug Use By Age Dataset        2KB  2019-04-26 15:02:02           1057
# austinreese/dril-tweets                                  Dril Tweets                                  663KB  2020-01-20 11:56:47             16
# fogallego/reviews-with-conditions                        Reviews with conditions                      339MB  2018-05-31 07:58:52            330
# pktippa/baby-names-analysis-dataset                      baby_names_analysis                            8MB  2019-08-11 06:23:15             18

# %%
# Creating a dataset directory
# !mkdir ./datasets
# !mkdir ./datasets/us-baby-name

# download the dataset from Kaggle and unzip it
# !kaggle datasets download kaggle/us-baby-names -f database.sqlite -p ./datasets/us-baby-name/database.sqlite
# !chdir ./datasets/us-baby-name/database.sqlite/
# !unzip ./datasets/us-baby-name/database.sqlite/*.zip  -d ./datasets/us-baby-name/database.sqlite
# Out:
# Downloading database.sqlite.zip to ./datasets/us-baby-name/database.sqlite
#  94% 123M/131M [00:03<00:00, 21.8MB/s]
# 100% 131M/131M [00:03<00:00, 40.8MB/s]
# /bin/bash: chdir: command not found
# Archive:  ./datasets/us-baby-name/database.sqlite/database.sqlite.zip
#   inflating: ./datasets/us-baby-name/database.sqlite/database.sqlite

# %%
# !unzip ./datasets/us-baby-name/database.sqlite/*.zip  -d ./datasets/us-baby-name/database.sqlite
# Out:
# Archive:  ./datasets/us-baby-name/database.sqlite/database.sqlite.zip
# replace ./datasets/us-baby-name/database.sqlite/database.sqlite? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ## 2. Working with SQLite
# ### Code Example - US Baby Names Dataset

# %% [markdown]
# In the first part, we downloaded an SQLite database into Colab. Let's connect to the dataset using the [sqlite3 package](https://docs.python.org/2/library/sqlite3.html): First, let's import the required packages, and answer several questions about the data.

# %%
import sqlite3
import matplotlib
import matplotlib.pyplot as plt
import os
# %matplotlib inline

DB_PATH = './datasets/us-baby-name/database.sqlite'

# %% [markdown]
# **Question 1: How many names in the dataset?**
#
# To answer this question, we need to run a query on the database. This can be done by doing following actions:
#
# 1.   We connect to the database, which is a local file, using the *connect* function.
# 2.   We create a *cursor object*.
# 3.   We call the *execute function* to run a query
# 4.   We fetch the results using the *fetchone* function

# %%
conn = sqlite3.connect(f'{DB_PATH}/database.sqlite') # connecting to the database
c = conn.cursor() # creating a cursor object
print("The number of national names in the dataset: %s" % c.execute("SELECT count(*) FROM NationalNames" ).fetchone()) # execute a query & fetch the results
print("The number of state names in the dataset: %s" % c.execute("SELECT count(*) FROM StateNames" ).fetchone()) 
c.close() # close the cursor
# Out:
# The number of national names in the dataset: 1825433
# The number of state names in the dataset: 5647426

# %% [markdown]
# **Question 2: How many distinct names in the Washington State? and in New York State?**

# %% [markdown]
# We can answer this question, by using the [Select Distinct] statment(https://www.w3schools.com/sql/sql_distinct.asp):

# %%
c = conn.cursor()
print("The number of distinct names in WA state is: %s" % c.execute("SELECT count(*) FROM StateNames Where State='WA'" ).fetchone())
print("The number of distinct names in NY state is: %s" % c.execute("SELECT count(*) FROM StateNames Where State='NY'" ).fetchone())
c.close()
# Out:
# The number of distinct names in WA state is: 114240
# The number of distinct names in NY state is: 277809

# %% [markdown]
# **Question 3: What are the most common/rare names?**

# %% [markdown]
# To answer this question, we need to count the number of times each name appeared in the dataset. This can be done by using the following steps: First, we will use the [Group By](https://www.w3schools.com/sql/sql_groupby.asp) statement, and SQL [Sum function](https://www.w3schools.com/sql/sql_count_avg_sum.asp). Second, we will use the [Order By](https://www.w3schools.com/sql/sql_orderby.asp) keyword to order the results. Lastly, we iterate through the retrieved results using a for loop:

# %%
c = conn.cursor()  
rows = c.execute("""SELECT Name, Sum(Count) as TotalNumberOfBabies
             FROM NationalNames
             Group By Name
             Order by Sum(Count)""" ) 
i = 1 
for r in rows:
  if i > 20:
    break
  print(f"{i}. {r[0]}, {r[1]}")
  i += 1
c.close() # close the cursor
# Out:
# 1. Aabid, 5
# 2. Aadhyan, 5
# 3. Aadian, 5
# 4. Aadrian, 5
# 5. Aadrit, 5
# 6. Aafreen, 5
# 7. Aagot, 5
# 8. Aahron, 5
# 9. Aaiyana, 5
# 10. Aaja, 5
# 11. Aakanksha, 5
# 12. Aakira, 5
# 13. Aakiyah, 5
# 14. Aaleeya, 5
# 15. Aalias, 5
# 16. Aalicia, 5
# 17. Aaliyaa, 5
# 18. Aallyah, 5
# 19. Aalon, 5
# 20. Aalyia, 5

# %% [markdown]
# Now let's print the names in descending order:

# %%
c = conn.cursor()  
rows = c.execute("""SELECT Name, Sum(Count) as TotalNumberOfBabies
             FROM NationalNames
             Group By Name
             Order by Sum(Count) DESC""" ) 
i = 1 
for r in rows:
  if i > 20:
    break
  print(f"{i}. {r[0]}, {r[1]}")
  i += 1
c.close() # close the cursor
# Out:
# 1. James, 5129096
# 2. John, 5106590
# 3. Robert, 4816785
# 4. Michael, 4330805
# 5. Mary, 4130441
# 6. William, 4071368
# 7. David, 3590557
# 8. Joseph, 2580687
# 9. Richard, 2564867
# 10. Charles, 2376700
# 11. Thomas, 2291517
# 12. Christopher, 2004177
# 13. Daniel, 1876880
# 14. Elizabeth, 1606282
# 15. Patricia, 1575529
# 16. Matthew, 1558671
# 17. Jennifer, 1467573
# 18. George, 1464430
# 19. Linda, 1454599
# 20. Barbara, 1437083

# %% [markdown]
# We can see that the most common names are James, and the rarest names are names that appeared a total of 5 times.
# *Can you guess why aren't any unique names in the database?*

# %% [markdown]
# ## 3. Working with Pony ORM

# %% [markdown]
# Object-relational mapping (ORM) is very useful for analyzing datasets. I like [Pony ORM](https://ponyorm.org) because it is really easy to use and work with. Moreover, Pony has easy to follow [documentation](https://docs.ponyorm.org). In this part of the notebook, we are going to work with Pony to transfer the database to object and objects into databases. Let's start by installing Pony ORM, and downloading the Pokemon Dataset and convert it into a database.

# %%
# !pip install pony
# Out:
# Collecting pony
#   Downloading https://files.pythonhosted.org/packages/fe/5e/f133d0559ca5015f0bd1089779c4b5ce115e728a6dd606a18dc529550fbb/pony-0.7.12.tar.gz (286kB)
#      |████████████████████████████████| 286kB 2.8MB/s
# Building wheels for collected packages: pony
#   Building wheel for pony (setup.py) ... done
#   Created wheel for pony: filename=pony-0.7.12-cp36-none-any.whl size=351612 sha256=cad43c8400456a93c3c801ca3829e9d1198b8021b6c079c9de294cdcb6d0471f
#   Stored in directory: /root/.cache/pip/wheels/c8/17/43/4f7d5034e6941b2837f090a788c3abfde02a2c6ddb542e98d7
# Successfully built pony
# Installing collected packages: pony
# Successfully installed pony-0.7.12

# %%
# !kaggle datasets list -s pokemon
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                  title                                       size  lastUpdated          downloadCount
# ---------------------------------------------------  -----------------------------------------  -----  -------------------  -------------
# abcsds/pokemon                                       Pokemon with stats                          15KB  2016-08-29 06:01:43          44149
# terminus7/pokemon-challenge                          Pokemon- Weedle's Cave                     285KB  2017-09-21 08:43:04          25636
# rounakbanik/pokemon                                  The Complete Pokemon Dataset                47KB  2017-09-29 19:49:32          17226
# vishalsubbiah/pokemon-images-and-types               Pokemon Image Dataset                        2MB  2018-12-17 01:01:39           3795
# thedagger/pokemon-generation-one                     Pokemon Generation One                       2GB  2018-08-02 06:47:33           2393
# kvpratama/pokemon-images-dataset                     Pokemon Images Dataset                      79MB  2017-12-12 03:45:47           3275
# mlomuscio/pokemon                                    Pokemon                                     14KB  2019-09-03 01:14:49            143
# mylesoneill/pokemon-sun-and-moon-gen-7-stats         Pokemon Sun and Moon (Gen 7) Stats         271KB  2019-11-17 22:16:07           1952
# brilja/pokemon-mugshots-from-super-mystery-dungeon   Pokemon Mugshots                            81MB  2019-05-21 04:09:03            159
# aaronyin/oneshotpokemon                              One-Shot-Pokemon Images                      2GB  2018-05-29 05:32:03            872
# lantian773030/pokemonclassification                  Pokemon Classification                     417MB  2019-11-09 23:15:13            122
# tristan581/17k-apple-app-store-strategy-games        17K Mobile Strategy Games                    8MB  2019-08-26 08:22:16          15669
# semioniy/predictemall                                Predict'em All                             140MB  2016-10-11 23:33:54           5831
# lrcusack/pokemontrainers                             Pokemon Trainers Dataset                   801KB  2017-04-08 06:59:35            494
# brkurzawa/original-150-pokemon-image-search-results  Original 151 Pokemon Image Search Results   20GB  2018-11-21 17:17:04            355
# dollarakshay/pokemon-images                          Pokemon Images                              57MB  2017-11-27 20:12:53            791
# abcsds/pokemongo                                     PokemonGO                                    4KB  2016-08-26 04:57:19           1746
# kveykva/sf-bay-area-pokemon-go-spawns                SF Bay Area Pokemon Go Spawns                4MB  2016-09-15 04:12:39           1104
# n2cholas/competitive-pokemon-dataset                 Complete Competitive Pokemon Dataset       172KB  2018-06-24 05:47:05            326
# sekarmg/pokemon                                      Pokemon                                    285KB  2017-11-29 03:01:57            475

# %%
# !kaggle datasets download abcsds/pokemon -p ./datasets/
# !unzip ./datasets/pokemon.zip -d ./datasets/pokemon/
# Out:
# Downloading pokemon.zip to ./datasets
#   0% 0.00/14.9k [00:00<?, ?B/s]
# 100% 14.9k/14.9k [00:00<00:00, 13.9MB/s]
# Archive:  ./datasets/pokemon.zip
#   inflating: ./datasets/pokemon/Pokemon.csv

# %%
# !ls ./datasets/pokemon
# Out:
# Pokemon.csv

# %% [markdown]
# ### 3.1 Creating DB using Objects

# %% [markdown]
# Now let's use the Pokemon dataset and Pony to create a database. The first step is to create classes that will map to tables in the generate database:

# %%
from pony.orm import *
# Creating a new database
db = Database()
db.bind(provider='sqlite', filename='/content/datasets/pokemon/pokemon.pony.db', create_db=True) # notice we can easily use other type of databases instead of SQLite

# Each class will be map to a table
class Trainer(db.Entity):
    name = Required(str)
    age = Required(int)
    pokemons_list = Set('Pokemon') # Connected to the Pokemon class
    
class Pokemon(db.Entity):
    name = Required(str) # cannot be None
    age  = Optional(int)
    attack_power = Required(int)
    defense_power = Required(int)
    trainer = Optional(Trainer) # Connected to the Trainer class

# %%
show(Trainer)
# Out:
# class Trainer(Entity):
#     id = PrimaryKey(int, auto=True)
#     name = Required(str)
#     age = Required(int)
#     pokemons_list = Set(Pokemon)

# %% [markdown]
# Notice that Pony adds a PrimaryKey to the Trainer class. Let's create the actual tables:

# %%
set_sql_debug(True) # helps to see what SQL commands are running
db.generate_mapping(create_tables=True) # create tables
# Out:
# GET CONNECTION FROM THE LOCAL POOL
# PRAGMA foreign_keys = false
# BEGIN IMMEDIATE TRANSACTION
# CREATE TABLE "Trainer" (
#   "id" INTEGER PRIMARY KEY AUTOINCREMENT,
#   "name" TEXT NOT NULL,
#   "age" INTEGER NOT NULL
# )
#
# CREATE TABLE "Pokemon" (
#   "id" INTEGER PRIMARY KEY AUTOINCREMENT,
#   "name" TEXT NOT NULL,
#   "age" INTEGER,
#   "attack_power" INTEGER NOT NULL,
#   "defense_power" INTEGER NOT NULL,
#   "trainer" INTEGER REFERENCES "Trainer" ("id") ON DELETE SET NULL
# )
#
# CREATE INDEX "idx_pokemon__trainer" ON "Pokemon" ("trainer")
#
# SELECT "Pokemon"."id", "Pokemon"."name", "Pokemon"."age", "Pokemon"."attack_power", "Pokemon"."defense_power", "Pokemon"."trainer"
# FROM "Pokemon" "Pokemon"
# WHERE 0 = 1
#
# SELECT "Trainer"."id", "Trainer"."name", "Trainer"."age"
# FROM "Trainer" "Trainer"
# WHERE 0 = 1
#
# COMMIT
# PRAGMA foreign_keys = true
# CLOSE CONNECTION

# %% [markdown]
# We can see that Pony create the Pokemon & the Trainer tables in the database. Next, we will use the Pandas package to insert data into these tables:

# %%
import pandas as pd # we will talk more about pandas in our next lecture
df = pd.read_csv('./datasets/pokemon/Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Let's iterate on the dataframe rows and create a Pokemon object from each row:

# %%
import random

for idx, row in df.iterrows():
    Pokemon(name=row['Name'],age=random.randint(0,500),attack_power=row['Sp. Atk'], defense_power=row['Sp. Def'])

# %% [markdown]
# We have created 800 objects, one for each row. However, none of them was committed to the DB yet. Let's commit!

# %%
commit()
# Out:
# GET NEW CONNECTION
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Bulbasaur', 371, 65, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ivysaur', 285, 80, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Venusaur', 4, 100, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['VenusaurMega Venusaur', 412, 122, 120]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Charmander', 17, 60, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Charmeleon', 291, 80, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Charizard', 26, 109, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['CharizardMega Charizard X', 50, 130, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['CharizardMega Charizard Y', 217, 159, 115]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Squirtle', 238, 50, 64]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wartortle', 85, 65, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Blastoise', 56, 85, 105]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['BlastoiseMega Blastoise', 498, 135, 115]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Caterpie', 295, 20, 20]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Metapod', 114, 25, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Butterfree', 171, 90, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Weedle', 174, 20, 20]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kakuna', 28, 25, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Beedrill', 305, 45, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['BeedrillMega Beedrill', 71, 15, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pidgey', 438, 35, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pidgeotto', 352, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pidgeot', 392, 70, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['PidgeotMega Pidgeot', 455, 135, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Rattata', 99, 25, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Raticate', 338, 50, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Spearow', 458, 31, 31]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Fearow', 200, 61, 61]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ekans', 316, 40, 54]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Arbok', 409, 65, 79]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pikachu', 421, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Raichu', 88, 90, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sandshrew', 267, 20, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sandslash', 181, 45, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nidoran♀', 257, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nidorina', 463, 55, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nidoqueen', 48, 75, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nidoran♂', 11, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nidorino', 437, 55, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nidoking', 452, 85, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Clefairy', 218, 60, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Clefable', 480, 95, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Vulpix', 198, 50, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ninetales', 316, 81, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Jigglypuff', 36, 45, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wigglytuff', 301, 85, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Zubat', 215, 30, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Golbat', 279, 65, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Oddish', 322, 75, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gloom', 353, 85, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Vileplume', 484, 110, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Paras', 387, 45, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Parasect', 383, 60, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Venonat', 115, 40, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Venomoth', 245, 90, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Diglett', 144, 35, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dugtrio', 451, 50, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Meowth', 12, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Persian', 301, 65, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Psyduck', 298, 65, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Golduck', 50, 95, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mankey', 225, 35, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Primeape', 283, 60, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Growlithe', 164, 70, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Arcanine', 68, 100, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Poliwag', 438, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Poliwhirl', 454, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Poliwrath', 257, 70, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Abra', 300, 105, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kadabra', 264, 120, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Alakazam', 362, 135, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['AlakazamMega Alakazam', 464, 175, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Machop', 451, 35, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Machoke', 468, 50, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Machamp', 341, 65, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Bellsprout', 218, 70, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Weepinbell', 296, 85, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Victreebel', 225, 100, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tentacool', 256, 50, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tentacruel', 259, 80, 120]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Geodude', 224, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Graveler', 285, 45, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Golem', 406, 55, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ponyta', 315, 65, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Rapidash', 223, 80, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Slowpoke', 39, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Slowbro', 446, 100, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['SlowbroMega Slowbro', 61, 130, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Magnemite', 281, 95, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Magneton', 419, 120, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ["Farfetch'd", 317, 58, 62]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Doduo', 399, 35, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dodrio', 487, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Seel', 431, 45, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dewgong', 269, 70, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Grimer', 399, 40, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Muk', 387, 65, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Shellder', 225, 45, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cloyster', 290, 85, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gastly', 302, 100, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Haunter', 363, 115, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gengar', 41, 130, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['GengarMega Gengar', 259, 170, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Onix', 100, 30, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Drowzee', 214, 43, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hypno', 144, 73, 115]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Krabby', 95, 25, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kingler', 89, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Voltorb', 435, 55, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Electrode', 407, 80, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Exeggcute', 339, 60, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Exeggutor', 272, 125, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cubone', 373, 40, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Marowak', 267, 50, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hitmonlee', 51, 35, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hitmonchan', 338, 35, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lickitung', 73, 60, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Koffing', 308, 60, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Weezing', 173, 85, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Rhyhorn', 98, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Rhydon', 177, 45, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Chansey', 265, 35, 105]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tangela', 239, 100, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kangaskhan', 437, 40, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['KangaskhanMega Kangaskhan', 248, 60, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Horsea', 297, 70, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Seadra', 378, 95, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Goldeen', 193, 35, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Seaking', 79, 65, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Staryu', 393, 70, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Starmie', 473, 100, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mr. Mime', 43, 100, 120]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Scyther', 277, 55, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Jynx', 119, 115, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Electabuzz', 190, 95, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Magmar', 251, 100, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pinsir', 324, 55, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['PinsirMega Pinsir', 215, 65, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tauros', 110, 40, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Magikarp', 488, 15, 20]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gyarados', 347, 60, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['GyaradosMega Gyarados', 479, 70, 130]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lapras', 260, 85, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ditto', 499, 48, 48]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Eevee', 350, 45, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Vaporeon', 391, 110, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Jolteon', 79, 110, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Flareon', 209, 95, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Porygon', 376, 85, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Omanyte', 276, 90, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Omastar', 90, 115, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kabuto', 245, 55, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kabutops', 385, 65, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Aerodactyl', 430, 60, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['AerodactylMega Aerodactyl', 476, 70, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Snorlax', 284, 65, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Articuno', 80, 95, 125]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Zapdos', 460, 125, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Moltres', 145, 125, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dratini', 195, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dragonair', 212, 70, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dragonite', 337, 100, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mewtwo', 241, 154, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['MewtwoMega Mewtwo X', 274, 154, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['MewtwoMega Mewtwo Y', 55, 194, 120]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mew', 221, 100, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Chikorita', 311, 49, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Bayleef', 214, 63, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Meganium', 24, 83, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cyndaquil', 226, 60, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Quilava', 98, 80, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Typhlosion', 316, 109, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Totodile', 486, 44, 48]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Croconaw', 86, 59, 63]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Feraligatr', 50, 79, 83]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sentret', 475, 35, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Furret', 386, 45, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hoothoot', 190, 36, 56]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Noctowl', 197, 76, 96]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ledyba', 119, 40, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ledian', 232, 55, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Spinarak', 226, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ariados', 426, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Crobat', 402, 70, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Chinchou', 460, 56, 56]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lanturn', 15, 76, 76]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pichu', 248, 35, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cleffa', 329, 45, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Igglybuff', 334, 40, 20]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Togepi', 500, 40, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Togetic', 213, 80, 105]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Natu', 430, 70, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Xatu', 350, 95, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mareep', 490, 65, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Flaaffy', 291, 80, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ampharos', 362, 115, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['AmpharosMega Ampharos', 334, 165, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Bellossom', 194, 90, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Marill', 35, 20, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Azumarill', 367, 60, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sudowoodo', 54, 30, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Politoed', 61, 90, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hoppip', 405, 35, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Skiploom', 310, 45, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Jumpluff', 411, 55, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Aipom', 449, 40, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sunkern', 281, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sunflora', 117, 105, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Yanma', 100, 75, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wooper', 374, 25, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Quagsire', 2, 65, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Espeon', 62, 130, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Umbreon', 472, 60, 130]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Murkrow', 43, 85, 42]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Slowking', 138, 100, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Misdreavus', 450, 85, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Unown', 378, 72, 48]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wobbuffet', 291, 33, 58]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Girafarig', 408, 90, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pineco', 113, 35, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Forretress', 337, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dunsparce', 348, 65, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gligar', 432, 35, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Steelix', 145, 55, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['SteelixMega Steelix', 21, 55, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Snubbull', 322, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Granbull', 397, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Qwilfish', 139, 55, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Scizor', 63, 55, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['ScizorMega Scizor', 12, 65, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Shuckle', 237, 10, 230]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Heracross', 359, 40, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['HeracrossMega Heracross', 444, 40, 105]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sneasel', 382, 35, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Teddiursa', 366, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ursaring', 224, 75, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Slugma', 201, 70, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Magcargo', 178, 80, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Swinub', 158, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Piloswine', 69, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Corsola', 272, 65, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Remoraid', 92, 65, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Octillery', 405, 105, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Delibird', 277, 65, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mantine', 11, 80, 140]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Skarmory', 490, 40, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Houndour', 311, 80, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Houndoom', 285, 110, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['HoundoomMega Houndoom', 467, 140, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kingdra', 478, 95, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Phanpy', 59, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Donphan', 156, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Porygon2', 411, 105, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Stantler', 215, 85, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Smeargle', 452, 20, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tyrogue', 280, 35, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hitmontop', 235, 35, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Smoochum', 201, 85, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Elekid', 225, 65, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Magby', 424, 70, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Miltank', 459, 40, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Blissey', 261, 75, 135]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Raikou', 323, 115, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Entei', 202, 90, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Suicune', 187, 90, 115]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Larvitar', 472, 45, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pupitar', 183, 65, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tyranitar', 369, 95, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['TyranitarMega Tyranitar', 258, 95, 120]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lugia', 128, 90, 154]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ho-oh', 58, 110, 154]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Celebi', 494, 100, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Treecko', 251, 65, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Grovyle', 325, 85, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sceptile', 301, 105, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['SceptileMega Sceptile', 228, 145, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Torchic', 206, 70, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Combusken', 331, 85, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Blaziken', 20, 110, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['BlazikenMega Blaziken', 298, 130, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mudkip', 150, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Marshtomp', 439, 60, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Swampert', 479, 85, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['SwampertMega Swampert', 140, 95, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Poochyena', 353, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mightyena', 282, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Zigzagoon', 151, 30, 41]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Linoone', 286, 50, 61]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wurmple', 96, 20, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Silcoon', 385, 25, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Beautifly', 225, 100, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cascoon', 454, 25, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dustox', 266, 50, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lotad', 118, 40, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lombre', 158, 60, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ludicolo', 105, 90, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Seedot', 154, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nuzleaf', 241, 60, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Shiftry', 265, 90, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Taillow', 427, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Swellow', 114, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wingull', 77, 55, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pelipper', 427, 85, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ralts', 19, 45, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kirlia', 3, 65, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gardevoir', 262, 125, 115]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['GardevoirMega Gardevoir', 63, 165, 135]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Surskit', 315, 50, 52]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Masquerain', 146, 80, 82]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Shroomish', 335, 40, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Breloom', 306, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Slakoth', 251, 35, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Vigoroth', 295, 55, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Slaking', 367, 95, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nincada', 254, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Ninjask', 474, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Shedinja', 262, 30, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Whismur', 334, 51, 23]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Loudred', 61, 71, 43]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Exploud', 470, 91, 73]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Makuhita', 302, 20, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hariyama', 32, 40, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Azurill', 262, 20, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Nosepass', 498, 45, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Skitty', 236, 35, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Delcatty', 302, 55, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sableye', 358, 65, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['SableyeMega Sableye', 94, 85, 115]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mawile', 32, 55, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['MawileMega Mawile', 343, 55, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Aron', 106, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lairon', 52, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Aggron', 259, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['AggronMega Aggron', 217, 60, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Meditite', 382, 40, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Medicham', 214, 60, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['MedichamMega Medicham', 266, 80, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Electrike', 110, 65, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Manectric', 474, 105, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['ManectricMega Manectric', 264, 135, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Plusle', 145, 85, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Minun', 82, 75, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Volbeat', 296, 47, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Illumise', 189, 73, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Roselia', 329, 100, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gulpin', 306, 43, 53]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Swalot', 488, 73, 83]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Carvanha', 31, 65, 20]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sharpedo', 271, 95, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['SharpedoMega Sharpedo', 24, 110, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wailmer', 395, 70, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wailord', 465, 90, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Numel', 58, 65, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Camerupt', 395, 105, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['CameruptMega Camerupt', 339, 145, 105]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Torkoal', 98, 85, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Spoink', 471, 70, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Grumpig', 113, 90, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Spinda', 325, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Trapinch', 26, 45, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Vibrava', 199, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Flygon', 245, 80, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cacnea', 89, 85, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cacturne', 164, 115, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Swablu', 403, 40, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Altaria', 89, 70, 105]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['AltariaMega Altaria', 191, 110, 105]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Zangoose', 64, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Seviper', 36, 100, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lunatone', 410, 95, 85]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Solrock', 363, 55, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Barboach', 7, 46, 41]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Whiscash', 317, 76, 71]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Corphish', 424, 50, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Crawdaunt', 295, 90, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Baltoy', 340, 40, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Claydol', 269, 70, 120]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lileep', 228, 61, 87]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cradily', 303, 81, 107]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Anorith', 119, 40, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Armaldo', 362, 70, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Feebas', 8, 10, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Milotic', 92, 100, 125]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Castform', 7, 70, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kecleon', 202, 60, 120]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Shuppet', 409, 63, 33]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Banette', 153, 83, 63]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['BanetteMega Banette', 144, 93, 83]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Duskull', 3, 30, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dusclops', 369, 60, 130]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tropius', 124, 72, 87]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Chimecho', 215, 95, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Absol', 90, 75, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['AbsolMega Absol', 281, 115, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Wynaut', 292, 23, 48]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Snorunt', 189, 50, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Glalie', 409, 80, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['GlalieMega Glalie', 358, 120, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Spheal', 290, 55, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sealeo', 18, 75, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Walrein', 378, 95, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Clamperl', 282, 74, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Huntail', 209, 94, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gorebyss', 258, 114, 75]
#
# ...
# ['Beheeyem', 83, 125, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Litwick', 374, 65, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Lampent', 474, 95, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Chandelure', 309, 145, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Axew', 236, 30, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Fraxure', 382, 40, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Haxorus', 315, 60, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cubchoo', 240, 60, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Beartic', 171, 70, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cryogonal', 379, 95, 135]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Shelmet', 155, 40, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Accelgor', 129, 100, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Stunfisk', 48, 81, 99]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mienfoo', 329, 55, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mienshao', 423, 95, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Druddigon', 253, 60, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Golett', 380, 35, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Golurk', 318, 55, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pawniard', 211, 40, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Bisharp', 275, 60, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Bouffalant', 35, 40, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Rufflet', 336, 37, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Braviary', 351, 57, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Vullaby', 269, 45, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Mandibuzz', 138, 55, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Heatmor', 438, 105, 66]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Durant', 56, 48, 48]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Deino', 286, 45, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Zweilous', 462, 65, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hydreigon', 187, 125, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Larvesta', 150, 50, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Volcarona', 85, 135, 105]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Cobalion', 34, 90, 72]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Terrakion', 456, 72, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Virizion', 405, 90, 129]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['TornadusIncarnate Forme', 60, 125, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['TornadusTherian Forme', 185, 110, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['ThundurusIncarnate Forme', 414, 125, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['ThundurusTherian Forme', 356, 145, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Reshiram', 281, 150, 120]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Zekrom', 432, 120, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['LandorusIncarnate Forme', 73, 115, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['LandorusTherian Forme', 184, 105, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Kyurem', 243, 130, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['KyuremBlack Kyurem', 156, 120, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['KyuremWhite Kyurem', 405, 170, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['KeldeoOrdinary Forme', 205, 129, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['KeldeoResolute Forme', 397, 129, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['MeloettaAria Forme', 119, 128, 128]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['MeloettaPirouette Forme', 481, 77, 77]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Genesect', 129, 120, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Chespin', 465, 48, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Quilladin', 220, 56, 58]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Chesnaught', 126, 74, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Fennekin', 83, 62, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Braixen', 0, 90, 70]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Delphox', 300, 114, 100]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Froakie', 157, 62, 44]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Frogadier', 74, 83, 56]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Greninja', 500, 103, 71]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Bunnelby', 150, 32, 36]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Diggersby', 178, 50, 77]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Fletchling', 475, 40, 38]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Fletchinder', 258, 56, 52]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Talonflame', 223, 74, 69]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Scatterbug', 355, 27, 25]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Spewpa', 277, 27, 30]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Vivillon', 198, 90, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Litleo', 8, 73, 54]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pyroar', 331, 109, 66]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Flabébé', 215, 61, 79]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Floette', 107, 75, 98]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Florges', 246, 112, 154]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Skiddo', 240, 62, 57]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Gogoat', 46, 97, 81]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pancham', 211, 46, 48]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Pangoro', 76, 69, 71]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Furfrou', 346, 65, 90]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Espurr', 382, 63, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['MeowsticMale', 422, 83, 81]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['MeowsticFemale', 23, 83, 81]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Honedge', 400, 35, 37]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Doublade', 396, 45, 49]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['AegislashBlade Forme', 379, 150, 50]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['AegislashShield Forme', 301, 50, 150]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Spritzee', 443, 63, 65]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Aromatisse', 297, 99, 89]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Swirlix', 317, 59, 57]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Slurpuff', 89, 85, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Inkay', 331, 37, 46]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Malamar', 468, 68, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Binacle', 151, 39, 56]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Barbaracle', 420, 54, 86]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Skrelp', 278, 60, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dragalge', 412, 97, 123]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Clauncher', 476, 58, 63]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Clawitzer', 111, 120, 89]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Helioptile', 322, 61, 43]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Heliolisk', 402, 109, 94]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tyrunt', 206, 45, 45]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Tyrantrum', 255, 69, 59]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Amaura', 287, 67, 63]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Aurorus', 428, 99, 92]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sylveon', 10, 110, 130]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Hawlucha', 260, 74, 63]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Dedenne', 351, 81, 67]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Carbink', 413, 50, 150]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Goomy', 451, 55, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Sliggoo', 84, 83, 113]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Goodra', 254, 110, 150]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Klefki', 160, 80, 87]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Phantump', 146, 50, 60]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Trevenant', 145, 65, 82]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['PumpkabooAverage Size', 340, 44, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['PumpkabooSmall Size', 131, 44, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['PumpkabooLarge Size', 362, 44, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['PumpkabooSuper Size', 437, 44, 55]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['GourgeistAverage Size', 317, 58, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['GourgeistSmall Size', 138, 58, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['GourgeistLarge Size', 184, 58, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['GourgeistSuper Size', 201, 58, 75]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Bergmite', 479, 32, 35]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Avalugg', 408, 44, 46]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Noibat', 259, 45, 40]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Noivern', 343, 97, 80]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Xerneas', 494, 131, 98]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Yveltal', 319, 131, 98]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Zygarde50% Forme', 263, 81, 95]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Diancie', 457, 100, 150]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['DiancieMega Diancie', 452, 160, 110]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['HoopaHoopa Confined', 66, 150, 130]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['HoopaHoopa Unbound', 303, 170, 130]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power") VALUES (?, ?, ?, ?)
# ['Volcanion', 459, 130, 90]
#
# COMMIT

# %% [markdown]
# Now let's add Ash as a trainer object, and add two pokemons trained by Ash:

# %%
ash_trainer = Trainer(name='Ash Ketchum', age=10)
pikachu = Pokemon(name='pikachu',age=6,attack_power=50, defense_power=50, trainer=ash_trainer)
charmander =  Pokemon(name='charmander',age=2,attack_power=60, defense_power=50,trainer=ash_trainer)
commit()
# Out:
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Trainer" ("name", "age") VALUES (?, ?)
# ['Ash Ketchum', 10]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power", "trainer") VALUES (?, ?, ?, ?, ?)
# ['pikachu', 6, 50, 50, 1]
#
# INSERT INTO "Pokemon" ("name", "age", "attack_power", "defense_power", "trainer") VALUES (?, ?, ?, ?, ?)
# ['charmander', 2, 60, 50, 1]
#
# COMMIT

# %% [markdown]
# We can now easily retrieve data using objects:

# %%
pikachu.trainer.age
# Out:
# 10

# %%
list(pikachu.trainer.pokemons_list)
# Out:
# [Pokemon[802], Pokemon[801]]

# %%
list(pikachu.trainer.pokemons_list)[1].name
# Out:
# 'pikachu'

# %% [markdown]
# We can also simply update the database using the created objects:

# %%
pikachu.age
# Out:
# 6

# %%
pikachu.age =110
commit()
# Out:
# BEGIN IMMEDIATE TRANSACTION
# UPDATE "Pokemon"
# SET "age" = ?
# WHERE "id" = ?
#   AND "name" = ?
#   AND "age" = ?
#   AND "attack_power" = ?
#   AND "defense_power" = ?
#   AND "trainer" = ?
# [110, 801, 'pikachu', 6, 50, 50, 1]
#
# COMMIT

# %%
pikachu.age
# Out:
# 110

# %% [markdown]
# ### 3.2 Creating  Objects from DB:

# %% [markdown]
# Using Pony, we can also connect to existing database, and easily search it without even knowing SQL. First let's connect between Pony to existing databse:

# %%
from pony.orm import *
db = Database()
db.bind(provider='sqlite', filename='/content/datasets/pokemon/pokemon.pony.db') # notice we don't use create_db=True here

class Trainer(db.Entity):
    name = Required(str)
    age = Required(int)
    pokemons_list = Set('Pokemon')
    
class Pokemon(db.Entity):
    name = Required(str) # cannot be None
    age  = Optional(int)
    attack_power = Required(int)
    defense_power = Required(int)
    trainer = Optional(Trainer)
db.generate_mapping()
set_sql_debug(True)
# Out:
# GET NEW CONNECTION
# RELEASE CONNECTION
# GET CONNECTION FROM THE LOCAL POOL
# SWITCH TO AUTOCOMMIT MODE
# SELECT "Pokemon"."id", "Pokemon"."name", "Pokemon"."age", "Pokemon"."attack_power", "Pokemon"."defense_power", "Pokemon"."trainer"
# FROM "Pokemon" "Pokemon"
# WHERE 0 = 1
#
# SELECT "Trainer"."id", "Trainer"."name", "Trainer"."age"
# FROM "Trainer" "Trainer"
# WHERE 0 = 1
#
# RELEASE CONNECTION
# RELEASE CONNECTION

# %% [markdown]
# Using Pony, we can also connect to existing database, and easily search it without even knowing SQL. First, let's connect between Pony to an existing database:

# %%
[i.name for i in select(p for p in Pokemon if p.attack_power >100 and p.defense_power > p.attack_power    )]
# Out:
# SELECT "p"."id", "p"."name", "p"."age", "p"."attack_power", "p"."defense_power", "p"."trainer"
# FROM "Pokemon" "p"
# WHERE "p"."attack_power" > 100
#   AND "p"."defense_power" > "p"."attack_power"
# ['Ho-oh',
#  'MetagrossMega Metagross',
#  'Latias',
#  'LatiasMega Latias',
#  'RotomHeat Rotom',
#  'RotomWash Rotom',
#  'RotomFrost Rotom',
#  'RotomFan Rotom',
#  'RotomMow Rotom',
#  'Florges',
#  'Sylveon',
#  'Goodra']

# %% [markdown]
# We can observe that behind the scenes Pony translate the query into a SQL query and returned a list with the names of the matched pokemons. Let's find the pokemon with the highest attack power:

# %%
m = max([i.attack_power for i in select(p for p in Pokemon  )])
m
# Out:
# SELECT "p"."id", "p"."name", "p"."age", "p"."attack_power", "p"."defense_power", "p"."trainer"
# FROM "Pokemon" "p"
# 194

# %%
[i.name for i in select(p for p in Pokemon if p.attack_power == m )]
# Out:
# SELECT "p"."id", "p"."name", "p"."age", "p"."attack_power", "p"."defense_power", "p"."trainer"
# FROM "Pokemon" "p"
# WHERE "p"."attack_power" = ?
# [194]
# ['MewtwoMega Mewtwo Y']

# %% [markdown]
# ## 4. SQL Big Data
# You can use SQL with various RDBMS to analyze tables with millions, tens of millions, or even hundreds of millions of rows. This is sufficient for most usages. However, it is also possible to use "SQL Like" queries to analyze Big Data with billions of rows (or even more). For example, it is possible to use  [HiveQL](https://www.tutorialspoint.com/hive/hiveql_select_where.htm) to analyze extremely large datasets on Hadoop, or [Spark SQL](https://spark.apache.org/sql/) to run SQL like queries on Spark.
#
# We will show an example of using HiveQL and Spark SQL in a future lecture. For, the last part of this lecture, let's run on a [Kaggle Kernel](https://www.youtube.com/watch?time_continue=1&v=FloMHMOU5Bs&feature=emb_logo), a simple example that utilizes SQL & BigQuery to query large scale datasets:

# %%
# see also https://www.kaggle.com/mrisdal/mentions-of-kaggle-on-hacker-news
# Run this on Kaggle Kernel
from google.cloud import bigquery


client = bigquery.Client()

query = """
SELECT title, time_ts
FROM `bigquery-public-data.hacker_news.stories`
WHERE title like '%big%data%'
ORDER BY time DESC
"""

query_job = client.query(query)
iterator = query_job.result(timeout=30)
rows = list(iterator)
# Transform the rows into a nice pandas dataframe
headlines = pd.DataFrame(data=[list(x.values()) for x in rows], columns=list(rows[0].keys()))

# Look at the first 10 headlines
headlines.head(10)

# %%
# see also https://www.kaggle.com/dhanushkishore/impact-of-game-of-thrones-on-us-baby-names
from google.cloud import bigquery

client = bigquery.Client()

query = """
SELECT gender, name, sum(number) as totalnames 
FROM `bigquery-public-data.usa_names.usa_1910_current` 
GROUP BY gender, name
Order by totalnames desc
"""

query_job = client.query(query)
iterator = query_job.result(timeout=30)
rows = list(iterator)
# Transform the rows into a nice pandas dataframe
headlines = pd.DataFrame(data=[list(x.values()) for x in rows], columns=list(rows[0].keys()))

# Look at the first 10 headlines
headlines.head(10)

# %% [markdown]
# ## Further Readings and Practice
#
#
# *   [SQLZoo](https://sqlzoo.net)
# *   [The SQL Murder Mystery](https://mystery.knightlab.com)
# *   [W3 School SQLL Tutorial](https://www.w3schools.com/sql/)
# *   [PonyORM](https://ponyorm.org)
# *   [Kaggle - Intro to SQL](https://www.kaggle.com/learn/intro-to-sql)
# *   [Getting Started with SQL and BigQuery notebook](https://www.kaggle.com/dansbecker/getting-started-with-sql-and-bigquery)
